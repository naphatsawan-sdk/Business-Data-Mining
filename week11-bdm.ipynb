# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/full-filled-brain-stroke-dataset/full_data.csv
# /kaggle/input/full-filled-brain-stroke-dataset/full_filled_stroke_data (1).csv

# %%
import warnings
warnings.simplefilter("ignore")

# %%
df = pd.read_csv("../input/full-filled-brain-stroke-dataset/full_data.csv")
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0             0              0           No        Private
# 4977    Male  40.0             0              0          Yes        Private
# 4978  Female  45.0             1              0          Yes       Govt_job
# 4979    Male  40.0             0              0          Yes        Private
# 4980  Female  80.0             1              0          Yes        Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0             Urban             228.69  36.6  formerly smoked       1
# 1             Rural             105.92  32.5     never smoked       1
# 2             Urban             171.23  34.4           smokes       1
# 3             Rural             174.12  24.0     never smoked       1
# 4             Urban             186.21  29.0  formerly smoked       1
# ...             ...                ...   ...              ...     ...
# 4976          Rural              70.15  29.8  formerly smoked       0
# 4977          Urban             191.15  31.1           smokes       0
# 4978          Rural              95.02  31.8           smokes       0
# 4979          Rural              83.94  30.0           smokes       0
# 4980          Urban              83.75  29.1     never smoked       0
#
# [4981 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4981 entries, 0 to 4980
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4981 non-null   object
#  1   age                4981 non-null   float64
#  2   hypertension       4981 non-null   int64
#  3   heart_disease      4981 non-null   int64
#  4   ever_married       4981 non-null   object
#  5   work_type          4981 non-null   object
#  6   Residence_type     4981 non-null   object
#  7   avg_glucose_level  4981 non-null   float64
#  8   bmi                4981 non-null   float64
#  9   smoking_status     4981 non-null   object
#  10  stroke             4981 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 428.2+ KB

# %%
df['gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['gender'] = df['gender'].replace('Male',0)
df['gender'] = df['gender'].replace('Female',1)
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0          0  67.0             0              1          Yes        Private
# 1          0  80.0             0              1          Yes        Private
# 2          1  49.0             0              0          Yes        Private
# 3          1  79.0             1              0          Yes  Self-employed
# 4          0  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976       0  41.0             0              0           No        Private
# 4977       0  40.0             0              0          Yes        Private
# 4978       1  45.0             1              0          Yes       Govt_job
# 4979       0  40.0             0              0          Yes        Private
# 4980       1  80.0             1              0          Yes        Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0             Urban             228.69  36.6  formerly smoked       1
# 1             Rural             105.92  32.5     never smoked       1
# 2             Urban             171.23  34.4           smokes       1
# 3             Rural             174.12  24.0     never smoked       1
# 4             Urban             186.21  29.0  formerly smoked       1
# ...             ...                ...   ...              ...     ...
# 4976          Rural              70.15  29.8  formerly smoked       0
# 4977          Urban             191.15  31.1           smokes       0
# 4978          Rural              95.02  31.8           smokes       0
# 4979          Rural              83.94  30.0           smokes       0
# 4980          Urban              83.75  29.1     never smoked       0
#
# [4981 rows x 11 columns]

# %%
df['ever_married'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['ever_married'] = df['ever_married'].replace('No',0)
df['ever_married'] = df['ever_married'].replace('Yes',1)
df
# Out:
#       gender   age  hypertension  heart_disease  ever_married      work_type  \
# 0          0  67.0             0              1             1        Private
# 1          0  80.0             0              1             1        Private
# 2          1  49.0             0              0             1        Private
# 3          1  79.0             1              0             1  Self-employed
# 4          0  81.0             0              0             1        Private
# ...      ...   ...           ...            ...           ...            ...
# 4976       0  41.0             0              0             0        Private
# 4977       0  40.0             0              0             1        Private
# 4978       1  45.0             1              0             1       Govt_job
# 4979       0  40.0             0              0             1        Private
# 4980       1  80.0             1              0             1        Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0             Urban             228.69  36.6  formerly smoked       1
# 1             Rural             105.92  32.5     never smoked       1
# 2             Urban             171.23  34.4           smokes       1
# 3             Rural             174.12  24.0     never smoked       1
# 4             Urban             186.21  29.0  formerly smoked       1
# ...             ...                ...   ...              ...     ...
# 4976          Rural              70.15  29.8  formerly smoked       0
# 4977          Urban             191.15  31.1           smokes       0
# 4978          Rural              95.02  31.8           smokes       0
# 4979          Rural              83.94  30.0           smokes       0
# 4980          Urban              83.75  29.1     never smoked       0
#
# [4981 rows x 11 columns]

# %%
df['work_type'].unique()
# Out:
# array(['Private', 'Self-employed', 'Govt_job', 'children'], dtype=object)

# %%
df['work_type'] = df['work_type'].replace('Private',0)
df['work_type'] = df['work_type'].replace('Self-employed',1)
df['work_type'] = df['work_type'].replace('Govt_job',2)
df['work_type'] = df['work_type'].replace('children',3)
df
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          0  67.0             0              1             1          0
# 1          0  80.0             0              1             1          0
# 2          1  49.0             0              0             1          0
# 3          1  79.0             1              0             1          1
# 4          0  81.0             0              0             1          0
# ...      ...   ...           ...            ...           ...        ...
# 4976       0  41.0             0              0             0          0
# 4977       0  40.0             0              0             1          0
# 4978       1  45.0             1              0             1          2
# 4979       0  40.0             0              0             1          0
# 4980       1  80.0             1              0             1          0
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0             Urban             228.69  36.6  formerly smoked       1
# 1             Rural             105.92  32.5     never smoked       1
# 2             Urban             171.23  34.4           smokes       1
# 3             Rural             174.12  24.0     never smoked       1
# 4             Urban             186.21  29.0  formerly smoked       1
# ...             ...                ...   ...              ...     ...
# 4976          Rural              70.15  29.8  formerly smoked       0
# 4977          Urban             191.15  31.1           smokes       0
# 4978          Rural              95.02  31.8           smokes       0
# 4979          Rural              83.94  30.0           smokes       0
# 4980          Urban              83.75  29.1     never smoked       0
#
# [4981 rows x 11 columns]

# %%
df['Residence_type'].unique()
# Out:
# array(['Urban', 'Rural'], dtype=object)

# %%
df['Residence_type'] = df['Residence_type'].replace('Urban',0)
df['Residence_type'] = df['Residence_type'].replace('Rural',1)
df
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          0  67.0             0              1             1          0
# 1          0  80.0             0              1             1          0
# 2          1  49.0             0              0             1          0
# 3          1  79.0             1              0             1          1
# 4          0  81.0             0              0             1          0
# ...      ...   ...           ...            ...           ...        ...
# 4976       0  41.0             0              0             0          0
# 4977       0  40.0             0              0             1          0
# 4978       1  45.0             1              0             1          2
# 4979       0  40.0             0              0             1          0
# 4980       1  80.0             1              0             1          0
#
#       Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0                  0             228.69  36.6  formerly smoked       1
# 1                  1             105.92  32.5     never smoked       1
# 2                  0             171.23  34.4           smokes       1
# 3                  1             174.12  24.0     never smoked       1
# 4                  0             186.21  29.0  formerly smoked       1
# ...              ...                ...   ...              ...     ...
# 4976               1              70.15  29.8  formerly smoked       0
# 4977               0             191.15  31.1           smokes       0
# 4978               1              95.02  31.8           smokes       0
# 4979               1              83.94  30.0           smokes       0
# 4980               0              83.75  29.1     never smoked       0
#
# [4981 rows x 11 columns]

# %%
df['smoking_status'].unique()
# Out:
# array(['formerly smoked', 'never smoked', 'smokes', 'Unknown'],
#       dtype=object)

# %%
df['smoking_status'] = df['smoking_status'].replace('never smoked',0)
df['smoking_status'] = df['smoking_status'].replace('formerly smoked',1)
df['smoking_status'] = df['smoking_status'].replace('smokes',2)
df['smoking_status'] = df['smoking_status'].replace('Unknown',3)
df
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          0  67.0             0              1             1          0
# 1          0  80.0             0              1             1          0
# 2          1  49.0             0              0             1          0
# 3          1  79.0             1              0             1          1
# 4          0  81.0             0              0             1          0
# ...      ...   ...           ...            ...           ...        ...
# 4976       0  41.0             0              0             0          0
# 4977       0  40.0             0              0             1          0
# 4978       1  45.0             1              0             1          2
# 4979       0  40.0             0              0             1          0
# 4980       1  80.0             1              0             1          0
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# 0                  0             228.69  36.6               1       1
# 1                  1             105.92  32.5               0       1
# 2                  0             171.23  34.4               2       1
# 3                  1             174.12  24.0               0       1
# 4                  0             186.21  29.0               1       1
# ...              ...                ...   ...             ...     ...
# 4976               1              70.15  29.8               1       0
# 4977               0             191.15  31.1               2       0
# 4978               1              95.02  31.8               2       0
# 4979               1              83.94  30.0               2       0
# 4980               0              83.75  29.1               0       0
#
# [4981 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4981 entries, 0 to 4980
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4981 non-null   int64
#  1   age                4981 non-null   float64
#  2   hypertension       4981 non-null   int64
#  3   heart_disease      4981 non-null   int64
#  4   ever_married       4981 non-null   int64
#  5   work_type          4981 non-null   int64
#  6   Residence_type     4981 non-null   int64
#  7   avg_glucose_level  4981 non-null   float64
#  8   bmi                4981 non-null   float64
#  9   smoking_status     4981 non-null   int64
#  10  stroke             4981 non-null   int64
# dtypes: float64(3), int64(8)
# memory usage: 428.2 KB

# %%
check = df.duplicated(keep='first')
sum(check)
# Out:
# 0

# %%
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
Xall = df.drop("stroke", axis = 1)
yall = df["stroke"]

# %%
from sklearn.model_selection import train_test_split
X, Xtmp, y, ytmp = train_test_split(Xall, yall, test_size=0.4, random_state=0)
Xv, Xt, yv, yt = train_test_split(Xtmp, ytmp, test_size=0.5, random_state=0)

# %%
from sklearn.preprocessing import MinMaxScaler
scl = MinMaxScaler().fit(X)
X = scl.transform(X)
Xv = scl.transform(Xv)
Xt = scl.transform(Xt)

# %%
import torch
class MLP(torch.nn.Module):  
 def __init__(self, n_inputs, num_classes, dropout):  
    super(MLP, self).__init__()  
    self.hidden1 = torch.nn.Linear(n_inputs, 30) 
    self.act1 = torch.nn.ReLU() 
    self.hidden2 = torch.nn.Linear(30, 20) 
    self.act2 = torch.nn.ReLU() 
    self.output = torch.nn.Linear(20, num_classes) 
    self.dropout = torch.nn.Dropout(p=dropout) 
 
 def forward(self, X): 
    X = self.hidden1(X)
    X = self.act1(X)
    X = self.hidden2(X)
    X = self.act2(X)
    X = self.dropout(X)
    X = self.output(X)
    return X

# %%
X
# Out:
# array([[0.        , 0.57275391, 0.        , ..., 0.14689318, 0.77586207,
#         0.33333333],
#        [0.        , 0.64599609, 0.        , ..., 0.31737605, 0.42241379,
#         1.        ],
#        [1.        , 0.01904297, 0.        , ..., 0.12635029, 0.02873563,
#         1.        ],
#        ...,
#        [1.        , 0.68261719, 0.        , ..., 0.78252239, 0.82471264,
#         0.        ],
#        [0.        , 0.69482422, 0.        , ..., 0.24175976, 0.44252874,
#         0.        ],
#        [1.        , 0.10888672, 0.        , ..., 0.1620349 , 0.13218391,
#         1.        ]])

# %%
y
# Out:
# 71      1
# 390     0
# 3355    0
# 2670    0
# 1334    0
#        ..
# 4931    0
# 3264    0
# 1653    0
# 2607    0
# 2732    0
# Name: stroke, Length: 2988, dtype: int64

# %%
from torch.utils.data import DataLoader, TensorDataset #เหมือนตัวเก็บข้อมูล ข้อมูลต้องเป็น float32 เท่านั้น และทำนายต้องเป็น int64 เท่านั้น
X = torch.from_numpy(X.astype(np.float32))   #ค่า x เป็น numpy อยู่แล้ว
y = torch.from_numpy(y.values.astype(np.int64)) #เปลี่ยนให้เป็น numpy array และเป็น int64

Xv = torch.from_numpy(Xv.astype(np.float32))
yv = torch.from_numpy(yv.values.astype(np.int64))

Xt = torch.from_numpy(Xt.astype(np.float32))
yt = torch.from_numpy(yt.values.astype(np.int64)) #บอกว่า true ก็เทรนสุ่ม 32 ตัวและเทรนไปเรื่อยๆ false โหลดทั้งหมดเข้าไปให้ทำนายเลย

train_dl = DataLoader(TensorDataset(X, y), batch_size=32, shuffle=True) #dataloader โหลดข้อมูลของเราเข้าไปใน deep learning เข้าไปเทรนทีละ 32 ตัวจนครบข้อมูลทั้งหมด
val_dl = DataLoader(TensorDataset(Xv, yv), batch_size=32, shuffle=False)
test_dl = DataLoader(TensorDataset(Xt, yt), batch_size=32, shuffle=False)

# %%
np.unique(y)
# Out:
# array([0, 1])

# %%
n_train, n_feat = X.shape
model = MLP(n_feat, 4, 0.5)                                   # 0.5 คือค่า dropout กัน overfiting
loss = torch.nn.CrossEntropyLoss()                            # ประกาศไว้ว่าจะหาความต่างระหว่าง output กับค่าโมเดล
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)  # จัดการเรื่องปรับจูนโมเดลต่างๆ optim.Adam เก่งที่สุดในการปรับค่าโมเดล lr(learning) คือความเร็วในการเรียนรู้ ปรับได้ตามใจ 0.1 - 0.000000001 เปลี่ยนแล้วดุว่า validation แม่นขึ้นไหม
for epoch in range(200):                                      # 20 รอบ พอไหมขึ้นอยู่กับ lr เรียน 100 รอบอาจจะเอ๋อนะคับ หมายถึงผมอะ
    model.train()                                             # Model in training mode เตรียมเรียนรู้
    tr_loss = []                                              # อยากเอาไว้เก็บค่า loss ที่เกิดขึ้นในแต่ละรอบ
    for i, (inputs, targets) in enumerate(train_dl): 
        optimizer.zero_grad()                                 # Clear gradients ค่าที่ต้องจูน ปรับให้เป็น 0 ก่อน 
        output = model(inputs)                                # Use forward pass เอา input เข้าไป เพื่อหา output
        l= loss(output, targets)                              # Calculate loss
        l.backward()                                          # Calculate gradients คำนวณว่าจะปรับอะไรเท่าไหร่ดี
        optimizer.step()                                      # Update model ปรับให้ค่าดีขึ้น
        tr_loss.append(l.item())                              # วนไปเรียนรู้เรื่อยๆ

        
#Validation

    model.eval() # Model in evaluation mode
    val_loss = []
    val_acc = []
    for i, (inputs, targets) in enumerate(val_dl):
        with torch.no_grad():
            output = model(inputs) 
        l= loss(output, targets)
        yp = torch.argmax(output, dim=1).flatten() ##
        val_acc.append(sum(yp==targets) / len(yp))
        val_loss.append(l.item())
 
    print("Train loss "+str(np.mean(tr_loss))+",Val loss "+str(np.mean(val_loss)) + ", Val Acc" + str(np.mean(val_acc))) #มาหาค่าเฉลี่ย
# Out:
# Train loss 0.8408879433223542,Val loss 0.26730595203116536, Val Acc0.95410156
# Train loss 0.30243537535375736,Val loss 0.21379814692772925, Val Acc0.95410156
# Train loss 0.2708871486656209,Val loss 0.19721337303053588, Val Acc0.95410156
# Train loss 0.25232049806955015,Val loss 0.18897426617331803, Val Acc0.95410156
# Train loss 0.22922163793539746,Val loss 0.18423540575895458, Val Acc0.95410156
# Train loss 0.23122379845602714,Val loss 0.18018068943638355, Val Acc0.95410156
# Train loss 0.22299693279126856,Val loss 0.17743477423209697, Val Acc0.95410156
# Train loss 0.21922945183642367,Val loss 0.1745365603128448, Val Acc0.95410156
# Train loss 0.2107341153983106,Val loss 0.17271122883539647, Val Acc0.95410156
# Train loss 0.20966582002237122,Val loss 0.17038719996344298, Val Acc0.95410156
# Train loss 0.21032118083948784,Val loss 0.1687133084051311, Val Acc0.95410156
# Train loss 0.20588109273701272,Val loss 0.16575472836848348, Val Acc0.95410156
# Train loss 0.20217939335456553,Val loss 0.16324565163813531, Val Acc0.95410156
# Train loss 0.20899888686835766,Val loss 0.1622210250934586, Val Acc0.95410156
# Train loss 0.19297810041523994,Val loss 0.1621348779881373, Val Acc0.95410156
# Train loss 0.19647271578457762,Val loss 0.159902521292679, Val Acc0.95410156
# Train loss 0.19265771403591683,Val loss 0.15985451557207853, Val Acc0.95410156
# Train loss 0.19151634433643616,Val loss 0.15660014876630157, Val Acc0.95410156
# Train loss 0.19185904104341853,Val loss 0.1559122777543962, Val Acc0.95410156
# Train loss 0.1971498966375564,Val loss 0.15678919292986393, Val Acc0.95410156
# Train loss 0.19073605588934522,Val loss 0.15413918253034353, Val Acc0.95410156
# Train loss 0.14880134385237667,Val loss 0.15861878881696612, Val Acc0.9560547
# Train loss 0.15105415294145016,Val loss 0.1564490171149373, Val Acc0.9550781
# Train loss 0.14845474296190003,Val loss 0.15601866296492517, Val Acc0.9550781
# Train loss 0.15171347655593714,Val loss 0.15803495311411098, Val Acc0.9550781
# Train loss 0.14729914065212646,Val loss 0.15562369476538152, Val Acc0.9550781
# Train loss 0.14997356896229247,Val loss 0.15630385803524405, Val Acc0.9550781
# Train loss 0.1488669264586048,Val loss 0.1561005775583908, Val Acc0.9550781
# Train loss 0.14914386535182278,Val loss 0.15741542319301516, Val Acc0.9550781
# Train loss 0.1494021360425556,Val loss 0.15578326536342502, Val Acc0.9550781
# Train loss 0.14641598755731544,Val loss 0.15590210480149835, Val Acc0.9550781
# Train loss 0.14832833845247614,Val loss 0.15660517779178917, Val Acc0.9550781
# Train loss 0.14709374231306163,Val loss 0.15612665528897196, Val Acc0.953125
# Train loss 0.14607267644494137,Val loss 0.15720238257199526, Val Acc0.95410156
# Train loss 0.14710344301853726,Val loss 0.15650812862440944, Val Acc0.95410156
# Train loss 0.1486374856309688,Val loss 0.15789184800814837, Val Acc0.95410156
# Train loss 0.15075552453623808,Val loss 0.157449432881549, Val Acc0.95410156
# Train loss 0.15000388303652723,Val loss 0.15879592869896442, Val Acc0.9550781
# Train loss 0.1498123558951502,Val loss 0.1601577737601474, Val Acc0.9550781
# Train loss 0.15071386130566292,Val loss 0.1579692760715261, Val Acc0.9550781
# Train loss 0.1470508568702226,Val loss 0.15850023785606027, Val Acc0.9550781
# Train loss 0.14597285011822872,Val loss 0.1590675190091133, Val Acc0.9550781
# Train loss 0.14564645845205226,Val loss 0.15825110068544745, Val Acc0.9550781
# Train loss 0.14697212204733429,Val loss 0.15829728520475328, Val Acc0.9550781
# Train loss 0.1501098144799471,Val loss 0.15984008309897035, Val Acc0.9550781
# Train loss 0.14620399405743847,Val loss 0.15817846998106688, Val Acc0.9550781

# %%
output
# Out:
# tensor([[   0.9112,   -0.3835,   -7.2197,   -6.9912],
#         [   2.8032,   -0.7950,  -29.8856,  -30.2564],
#         [  11.5835,   -3.9670, -107.9206, -111.5755],
#         [   8.4683,   -2.8087,  -79.4984,  -82.0172]])

# %%
output.argmax(dim=1)
# Out:
# tensor([0, 0, 0, 0])

# %%
model.eval() # Model in evaluation mode
ts_loss = []
yp = []
for i, (inputs, targets) in enumerate(val_dl):
    with torch.no_grad():
            output = model(inputs) 
    pred = torch.argmax(output, dim=1).flatten() 
    yp = list(pred.cpu().numpy()) if len(yp) == 0 else yp + list(pred.cpu().numpy()) 
sum(yp==yv.cpu().numpy())/len(yv)
# Out:
# 0.9538152610441767

# %%
model.eval() # Model in evaluation mode
ts_loss = []
yp = []
for i, (inputs, targets) in enumerate(val_dl):
    with torch.no_grad():
            output = model(inputs) 
    pred = torch.argmax(output, dim=1).flatten() 
    yp = list(pred.cpu().numpy()) if len(yp) == 0 else yp + list(pred.cpu().numpy()) 
sum(yp==yv.cpu().numpy())/len(yv)
# Out:
# 0.9538152610441767
